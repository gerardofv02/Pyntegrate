# %%
import Pyntegrate
import matplotlib.pyplot as plt

# %%
df = Pyntegrate.results_table.DEseq2Results("/home/jerry/Documentos/Python3.10/prueba/realData/desq2_Sanchez.csv",  import_kwargs=dict(index_col=1))
df.head()
# Out:
#            Unnamed: 0      baseMean  log2FoldChange     lfcSE       stat  \
# gene_name
# Serpina6            0  2.582347e+03        8.647607  0.462682  18.690160
# Amy2b               1  8.044688e+03       -6.156047  0.332255 -18.528052
# Amy2a5              2  1.831815e+03       -6.452610  0.368747 -17.498724
# Pnlip               3  1.867643e+06       -9.278741  0.567521 -16.349593
# Amy2-ps1            4  1.993706e+02       -6.906932  0.445029 -15.520171
#
#                  pvalue          padj
# gene_name
# Serpina6   5.953423e-78  8.933706e-74
# Amy2b      1.226470e-76  9.202202e-73
# Amy2a5     1.465146e-68  7.328660e-65
# Pnlip      4.378933e-60  1.642757e-56
# Amy2-ps1   2.533745e-54  7.604276e-51

# %%
fig = df.volcano_plot(column_name_padj="padj",
                       log2FoldChange_upper = 1.5,
                       log2FoldChange_lower=-1.5,
                       nlog10_upper=2,
                       text_nlog10=40,
                       text_log2FoldChange=6 )
# Out:
#            Unnamed: 0      baseMean  log2FoldChange     lfcSE       stat  \
# gene_name
# Serpina6            0  2.582347e+03        8.647607  0.462682  18.690160
# Amy2b               1  8.044688e+03       -6.156047  0.332255 -18.528052
# Amy2a5              2  1.831815e+03       -6.452610  0.368747 -17.498724
# Pnlip               3  1.867643e+06       -9.278741  0.567521 -16.349593
# Amy2-ps1            4  1.993706e+02       -6.906932  0.445029 -15.520171
#
#                  pvalue          padj gene_name     nlog10          color
# gene_name
# Serpina6   5.953423e-78  8.933706e-74  Serpina6  73.048968    upregulated
# Amy2b      1.226470e-76  9.202202e-73     Amy2b  72.036108  downregulated
# Amy2a5     1.465146e-68  7.328660e-65    Amy2a5  64.134975  downregulated
# Pnlip      4.378933e-60  1.642757e-56     Pnlip  55.784427  downregulated
# Amy2-ps1   2.533745e-54  7.604276e-51  Amy2-ps1  50.118942  downregulated
